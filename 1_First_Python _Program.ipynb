# %% [markdown]
# ## Download Python - https://www.python.org/
#
# Install Python -
# ![install-python3.png](attachment:d4ee4c93-e2a8-4bab-bbf9-98833532d296.png)

# %% [markdown]
# ## Install OR Try it your Browser - https://jupyter.org/

# %% [markdown]
# ## First Python Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Python Shell Like A Calculator
#
# Our Python shell can also work as a calculator. Addition, subtraction, multiplication, division, modulus etc

# %%
# Addition
10 + 10
# Out:
# 20

# %%
# Subtraction
20 - 10
# Out:
# 10

# %%
# Multiplication
4 * 4
# Out:
# 16

# %%
# Division
20 / 4
# Out:
# 5.0

# %%
# Modules
11 % 2
# Out:
# 1

# %%
# Python Sheel also use for complex calculation
(2+3) * 4 - ( 4 + 5)
# Out:
# 11

# %% [markdown]
# # Thank you
